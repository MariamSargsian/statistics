# %%
import matplotlib.pyplot as plt
from scipy import stats
xk = (1,4,2,7,8)
pk = (0.3, 0.1, 0.15, 0.08, 0.37)
custm = stats.rv_discrete(name='custm', values=(xk, pk))

fig, ax = plt.subplots(1, 1)
ax.plot(xk, custm.pmf(xk), 'ro', ms=12, mec='r')
ax.vlines(xk, 0, custm.pmf(xk), colors='r', lw=4)
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy import stats
xk = (1,4,2,7,8)
pk = (0.3, 0.1, 0.15, 0.08, 0.37)
custm = stats.rv_discrete(name='custm', values=(xk, pk))

fig, ax = plt.subplots(1, 1)
ax.plot(xk, custm.cdf(xk), ms=12, mec='r')
ax.vlines(xk, 0, custm.cdf(xk), colors='b', lw=10)
plt.show()

# %%
custm.mean()
# Out:
# 4.52

# %%
custm.var()
# Out:
# 9.669600000000006

# %%
#1st moment is mean
#2nd moment is variance
#3th moment is skewness
#4th moment is kurtosis

# %%
#central moments
from scipy.stats import moment
moment(pk, moment=2)
# Out:
# 0.01316

# %%
from scipy.stats import kurtosis
kurtosis(pk)
# Out:
# -1.5578246690256004

# %%
from scipy.stats import skew
skew(pk)
# Out:
# 0.4053849190517634

# %%
# generate random floating point values
from random import random

res=[]
# generate random numbers between 0-1
for i in range(1000):
    res.append(random())

# %%
res
# Out:
# [0.06110233455522218,
#  0.2268000795716596,
#  0.45101995079842616,
#  0.9379726371355496,
#  0.8157369227074764,
#  0.15922439142836786,
#  0.94275896220018,
#  0.7087926470571385,
#  0.34803246251208153,
#  0.7369967457169381,
#  0.6560968551319474,
#  0.6027647761921965,
#  0.28814495827620035,
#  0.37784852596299945,
#  0.8648009424581611,
#  0.452223747232808,
#  0.9803627256017942,
#  0.8017053594593483,
#  0.4392834115437665,
#  0.9914555534230539,
#  0.6912256853136652,
#  0.939694276539353,
#  0.41817508487048494,
#  0.0370167441232826,
#  0.035952334099775274,
#  0.8648616737711113,
#  0.7815356386795126,
#  0.5168799619747773,
#  0.3772635523692548,
#  0.6107662406977304,
#  0.05336311198365695,
#  0.42592390195840113,
#  0.9393763749880248,
#  0.7996576173035781,
#  0.5741428628535333,
#  0.24173434115144132,
#  0.4562295901843646,
#  0.5927029814961811,
#  0.3215919553627803,
#  0.4759166210860265,
#  0.8010361796552121,
#  0.4225394421398152,
#  0.09912156911628689,
# ...

# %%
lst = [round(num, 2) for num in res]

# %%
lst
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-b5cada25ed2a> in <module>
# ----> 1 lst
#
# NameError: name 'lst' is not defined

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

x = random.binomial(n=22, p=0.5, size=1000)
y = random.binomial(n=44, p=0.25, size=1000)
z = random.binomial(n=55, p=0.2, size=1000)
sns.distplot(x, kde=False)
sns.distplot(y, kde=False)
sns.distplot(random.poisson(lam=11, size=1000), kde=False,label='poisson')

plt.show()
# Out:
# /home/msargsyan/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#poisson 
mean=11
var = 11

# %%
#binomial
n=22
p=0.5
mean=n*p
var = n*p*(1-p)
# Out:
# 5.5

# %%
mean
# Out:
# 11.0

# %%
var
# Out:
# 5.5
